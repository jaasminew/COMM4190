# %% [markdown]
# # Case of the fake Biden robocall

# %% [markdown]
# * Coverage: https://www.nytimes.com/2024/01/22/business/media/biden-robocall-ai-new-hampshire.html
# * Audio of call: https://www.youtube.com/watch?v=FCs_zFbkf0M

# %% [markdown]
# ![](attachment:e527392c-a1d0-4be0-9fe1-e20b7c53ef84.png)
#
# ![](attachment:c046800f-15db-49f1-bc0c-e7d14d059f69.png)
#
# ![](attachment:c9786863-7736-466a-8d33-af728a438f9e.png)
#
# ![](attachment:6340dbd6-2984-4066-80a7-711eac9d9c92.png)
#
# ![](attachment:f24698b3-c978-4d72-8ca6-a8c062823338.png)
#
# ![](attachment:40b8a2f6-9c4f-43b8-8cf8-1e6114967916.png)
